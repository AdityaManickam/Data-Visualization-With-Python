# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
a = pd.read_csv(r'C:\Users\nesh\Desktop\Jupyter Notebook Files\avocado.csv')

# %%
a.head()
# Out:
#          Date  AveragePrice  Total Volume  Small Hass  Large Hass  XL Hass  \
# 0  27/12/2015          1.33      64236.62     1036.74    54454.85    48.16
# 1  20/12/2015          1.35      54876.98      674.28    44638.81    58.33
# 2  13/12/2015          0.93     118220.22      794.70   109149.67   130.50
# 3   6/12/2015          1.08      78992.15     1132.00    71976.41    72.58
# 4  29/11/2015          1.28      51039.60      941.48    43838.39    75.78
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags          Type  Year  Region
# 0     8696.87     8603.62       93.25          0.0  conventional  2015  Albany
# 1     9505.56     9408.07       97.49          0.0  conventional  2015  Albany
# 2     8145.35     8042.21      103.14          0.0  conventional  2015  Albany
# 3     5811.16     5677.40      133.76          0.0  conventional  2015  Albany
# 4     6183.95     5986.26      197.69          0.0  conventional  2015  Albany

# %%
sns.set_style('dark')

# %%
sns.lineplot(x='Date',y='AveragePrice',data=a) #Can change n_boot=1000 and ci=95 values
# Out:
# <AxesSubplot:xlabel='Date', ylabel='AveragePrice'>

# %%
sns.lineplot(x='Date',y='AveragePrice',data=a,n_boot=10)
# Out:
# <AxesSubplot:xlabel='Date', ylabel='AveragePrice'>

# %%
sns.lineplot(x='Date',y='AveragePrice',data=a,ci=50)
# Out:
# <AxesSubplot:xlabel='Date', ylabel='AveragePrice'>

# %%
sns.lineplot(x='Date',y='AveragePrice',data=a,ci=None)
# Out:
# <AxesSubplot:xlabel='Date', ylabel='AveragePrice'>

# %%
sns.lineplot(x='Date', y='AveragePrice', data=a,
             estimator='mean'); #Can also use 'sum' estimator

# %%
sns.lineplot(x='Date',y='AveragePrice',data=a,hue='Type')
# Out:
# <AxesSubplot:xlabel='Date', ylabel='AveragePrice'>
