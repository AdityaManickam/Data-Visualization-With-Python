# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
a = sns.load_dataset("tips")

# %%
sns.barplot(x='day', y='tip',data=a)
# Out:
# <AxesSubplot:xlabel='day', ylabel='tip'>

# %%
sns.barplot(x='day', y='total_bill',data=a)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.barplot(x='day', y='tip',data=a, hue='sex')
# Out:
# <AxesSubplot:xlabel='day', ylabel='tip'>

# %%
sns.barplot(x='day', y='tip',data=a, hue='sex',palette='winter_r')
# Out:
# <AxesSubplot:xlabel='day', ylabel='tip'>

# %%
sns.barplot(x='day', y='total_bill',data=a, hue='smoker')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.barplot(x='total_bill', y='day',data=a, hue='smoker')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='day'>

# %%
sns.barplot(x='day', y='tip',data=a,palette='spring',order=['Sat','Fri','Sun','Thur'])
# Out:
# <AxesSubplot:xlabel='day', ylabel='tip'>

# %%
sns.barplot(x='smoker', y='tip',data=a)
# Out:
# <AxesSubplot:xlabel='smoker', ylabel='tip'>

# %%
sns.barplot(x='smoker', y='tip',data=a, estimator=median)
# Out:
# <AxesSubplot:xlabel='smoker', ylabel='tip'>

# %%
from numpy import median

# %%
sns.barplot(x='smoker', y='tip',data=a, estimator=median, ci=50)
# Out:
# <AxesSubplot:xlabel='smoker', ylabel='tip'>

# %%
sns.barplot(x='smoker', y='tip',data=a, estimator=median, hue='sex',palette='coolwarm')
# Out:
# <AxesSubplot:xlabel='smoker', ylabel='tip'>

# %%
sns.barplot(x='day', y='total_bill',data=a, hue='smoker',capsize=0.3)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.barplot(x='size', y='tip',data=a,palette='autumn')
# Out:
# <AxesSubplot:xlabel='size', ylabel='tip'>

# %%
sns.barplot(x='size', y='tip',data=a,color='blue',capsize=0.15)
# Out:
# <AxesSubplot:xlabel='size', ylabel='tip'>

# %%
sns.barplot(x='size', y='tip',data=a,color='blue',saturation=0.3,capsize=0.15)
# Out:
# <AxesSubplot:xlabel='size', ylabel='tip'>
